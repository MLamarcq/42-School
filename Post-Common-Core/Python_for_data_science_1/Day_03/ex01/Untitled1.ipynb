# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('life_expectancy_years.csv')

# %%
data
# Out:
#                   country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0             Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1
# 1                  Angola  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0
# 2                 Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4
# 3                 Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    United Arab Emirates  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7
# ..                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 190                 Samoa  25.4  25.4  25.4  25.4  25.4  25.4  25.4  25.4
# 191                 Yemen  23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4
# 192          South Africa  33.5  33.5  33.5  33.5  33.5  33.5  33.5  33.5
# 193                Zambia  32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6
# 194              Zimbabwe  33.7  33.7  33.7  33.7  33.7  33.7  33.7  33.7
#
#      1808  ...  2091  2092  2093  2094  2095  2096  2097  2098  2099  2100
# ...

# %%
data.loc[1:3, ('1804', '1805')]
# Out:
#    1804  1805
# 1  27.0  27.0
# 2  35.4  35.4
# 3   NaN   NaN

# %%
data
# Out:
#                   country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0             Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1
# 1                  Angola  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0
# 2                 Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4
# 3                 Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    United Arab Emirates  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7
# ..                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 190                 Samoa  25.4  25.4  25.4  25.4  25.4  25.4  25.4  25.4
# 191                 Yemen  23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4
# 192          South Africa  33.5  33.5  33.5  33.5  33.5  33.5  33.5  33.5
# 193                Zambia  32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6
# 194              Zimbabwe  33.7  33.7  33.7  33.7  33.7  33.7  33.7  33.7
#
#      1808  ...  2091  2092  2093  2094  2095  2096  2097  2098  2099  2100
# ...

# %%
country = data.groupby(['country'])

# %%
country.groups
# Out:
# {'Afghanistan': [0], 'Albania': [2], 'Algeria': [49], 'Andorra': [3], 'Angola': [1], 'Antigua and Barbuda': [7], 'Argentina': [5], 'Armenia': [6], 'Australia': [8], 'Austria': [9], 'Azerbaijan': [10], 'Bahamas': [18], 'Bahrain': [17], 'Bangladesh': [15], 'Barbados': [24], 'Belarus': [20], 'Belgium': [12], 'Belize': [21], 'Benin': [13], 'Bhutan': [26], 'Bolivia': [22], 'Bosnia and Herzegovina': [19], 'Botswana': [27], 'Brazil': [23], 'Brunei': [25], 'Bulgaria': [16], 'Burkina Faso': [14], 'Burundi': [11], 'Cambodia': [91], 'Cameroon': [34], 'Canada': [29], 'Cape Verde': [39], 'Central African Republic': [28], 'Chad': [168], 'Chile': [31], 'China': [32], 'Colombia': [37], 'Comoros': [38], 'Congo, Dem. Rep.': [35], 'Congo, Rep.': [36], 'Costa Rica': [40], 'Cote d'Ivoire': [33], 'Croatia': [74], 'Cuba': [41], 'Cyprus': [42], 'Czech Republic': [43], 'Denmark': [47], 'Djibouti': [45], 'Dominica': [46], 'Dominican Republic': [48], 'Ecuador': [50], 'Egypt': [51], 'El Salvador': [155], 'Equat
# ...

# %%
france = country.get_group(('France',))

# %%
france
# Out:
#    country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  2091  \
# 58  France  34.0  36.4  34.4  30.6  29.4  34.9  35.0  34.2  34.5  ...  91.3
#
#     2092  2093  2094  2095  2096  2097  2098  2099  2100
# 58  91.4  91.5  91.7  91.8  91.9  92.0  92.1  92.2  92.3
#
# [1 rows x 302 columns]

# %%
print(type(france))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
france.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2091', '2092', '2093', '2094', '2095', '2096', '2097', '2098', '2099',
#        '2100'],
#       dtype='object', length=301)

# %%
print(f"le resultat est: {france.iloc[0]}")
# Out:
# le resultat est: 1800    34.0
# 1801    36.4
# 1802    34.4
# 1803    30.6
# 1804    29.4
#         ...
# 2096    91.9
# 2097    92.0
# 2098    92.1
# 2099    92.2
# 2100    92.3
# Name: 58, Length: 301, dtype: float64

# %%
x_axes = france.columns

# %%
y_axes = france.iloc[0, : ]

# %%
x_axes = [int(labels) for labels in x_axes]
y_axes = [float(labels) for labels in y_axes]
x_axes
# Out:
# [1800,
#  1801,
#  1802,
#  1803,
#  1804,
#  1805,
#  1806,
#  1807,
#  1808,
#  1809,
#  1810,
#  1811,
#  1812,
#  1813,
#  1814,
#  1815,
#  1816,
#  1817,
#  1818,
#  1819,
#  1820,
#  1821,
#  1822,
#  1823,
#  1824,
#  1825,
#  1826,
#  1827,
#  1828,
#  1829,
#  1830,
#  1831,
#  1832,
#  1833,
#  1834,
#  1835,
#  1836,
#  1837,
#  1838,
#  1839,
#  1840,
#  1841,
#  1842,
#  1843,
#  1844,
#  1845,
#  1846,
#  1847,
#  1848,
#  1849,
#  1850,
#  1851,
#  1852,
#  1853,
#  1854,
#  1855,
#  1856,
#  1857,
#  1858,
#  1859,
#  1860,
#  1861,
#  1862,
#  1863,
#  1864,
#  1865,
#  1866,
#  1867,
#  1868,
#  1869,
#  1870,
#  1871,
#  1872,
#  1873,
#  1874,
#  1875,
#  1876,
#  1877,
#  1878,
#  1879,
#  1880,
#  1881,
#  1882,
#  1883,
#  1884,
#  1885,
#  1886,
#  1887,
#  1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1893,
#  1894,
#  1895,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
# ...

# %%
plt.xlim(1790, 2110)
plt.xticks(range(1800, 2100, 40))
plt.xlabel('years')
plt.ylabel('life_expectancy')
plt.title('France Life expectancy Projections')
plt.plot(x_axes, y_axes)

# %%
plt.plot(x_axes, y_axes)

# %%
p
